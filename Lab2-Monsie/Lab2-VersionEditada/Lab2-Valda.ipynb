# %% [markdown]
# # Laboratorio 2

# %% [markdown]
# Se importan librerías esenciales: os para manejar rutas, numpy para cálculo numérico, pandas para manipulación de datos, matplotlib y mpl_toolkits.mplot3d para graficación 2D y 3D, y %matplotlib inline para que las gráficas se muestren dentro del cuaderno.

# %%
# utilizado para manejos de directorios y rutas
#Estudiante: Valda Plaza Camila Monserrat
#Carrera: Ing. Sistemas
import os

# Computacion vectorial y cientifica para python
import numpy as np

import pandas as pd  # importar pandas

# Librerias para graficación (trazado de gráficos)
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D  # Necesario para graficar superficies 3D

# llama a matplotlib a embeber graficas dentro de los cuadernillos
# %matplotlib inline

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Regresión lineal con multiples variables
# Se carga el dataset melb_data.csv, se rellenan valores nulos (mediana para numéricos, moda para categóricos), se seleccionan 10 columnas como características X y Price como variable objetivo y. Se imprime m (número de registros) y se muestran las primeras 10 filas de algunas columnas para verificar los datos.

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Lab2-Monsie/melb_data.csv')
# Preprosesamiento de rellenar valores nulos en columnas numéricas con la mediana y en columnas no numéricas con la moda
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].fillna(df[col].mode()[0])
    else:
        df[col] = df[col].fillna(df[col].median())

X = df[['Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
        'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
        'Propertycount']].values
y = df['Price'].values
m = y.size
print(m)

print('{:>8s}{:>8s}{:>10s}'.format('X[:,0]', 'X[:, 1]', 'y'))
print('-'*26)
for i in range(10):
    print('{:8.0f}{:8.0f}{:10.0f}'.format(X[i, 0], X[i, 1], y[i]))
# Out:
# 13580
#   X[:,0] X[:, 1]         y
# --------------------------
#        2       2   1480000
#        2       2   1035000
#        2       3   1465000
#        2       3    850000
#        2       3   1600000
#        2       2    941000
#        2       4   1876000
#        2       2   1636000
#        2       1    300000
#        2       3   1097000

# %% [markdown]
# Se muestra un bloque comentado que servía para revisar y limpiar valores nulos, indicando cómo se reemplazan con la mediana. Se decidió ya no hacer la limpieza dado que se perdía el 50% de los datos originalmente.

# %%
# DEFINIR las columnas a limpiar
# columns_to_clean = ['Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
                    #'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
                    #'Propertycount', 'Price']

# Mostrar valores nulos antes de limpiar
# print("Valores nulos ANTES de limpiar:")
# for col in columns_to_clean:
   # if col in df.columns:
       # nulls = df[col].isnull().sum()
       # if nulls > 0:
            # print(f"{col}: {nulls} valores nulos")
#
#print("\n" + "="*40 + "\n")

# Limpiar valores nulos con la mediana
# for col in columns_to_clean:
   # if col in df.columns:
       # median_value = df[col].median()
      #  nulls_before = df[col].isnull().sum()
       # df[col].fillna(median_value, inplace=True)
        # if nulls_before > 0:
          #  print(f"{col}: {nulls_before} nulos → reemplazados con mediana {median_value:.2f}")

# print("\nValores nulos DESPUÉS de limpiar:")
# print(df[columns_to_clean].isnull().sum())
# print("\n" + "="*40 + "\n")

# %% [markdown]
# La función `featureNormalize` recibe una matriz de datos y devuelve una versión normalizada, donde a cada columna se le resta su media y se divide entre su desviación estándar; además, retorna los valores de la media y la desviación de cada columna para poder reutilizarlos.

# %%
def  featureNormalize(X):

    X_norm = X.copy()
    mu = np.zeros(X.shape[1])
    sigma = np.zeros(X.shape[1])

    mu = np.mean(X, axis = 0)
    sigma = np.std(X, axis = 0)
    X_norm = (X - mu) / sigma

    return X_norm, mu, sigma

# %% [markdown]
# llama featureNormalize con los datos cargados

# %%
X_norm, mu, sigma = featureNormalize(X)

print(X)
print('Media calculada:', mu)
print('Desviación estandar calculada:', sigma)
print(X_norm)
# Out:
# [[ 2.5000000e+00  2.0000000e+00  1.0000000e+00 ... -3.7799600e+01
#    1.4499840e+02  4.0190000e+03]
#  [ 2.5000000e+00  2.0000000e+00  1.0000000e+00 ... -3.7807900e+01
#    1.4499340e+02  4.0190000e+03]
#  [ 2.5000000e+00  3.0000000e+00  2.0000000e+00 ... -3.7809300e+01
#    1.4499440e+02  4.0190000e+03]
#  ...
#  [ 6.8000000e+00  3.0000000e+00  2.0000000e+00 ... -3.7852740e+01
#    1.4488738e+02  6.3800000e+03]
#  [ 6.8000000e+00  4.0000000e+00  1.0000000e+00 ... -3.7859080e+01
#    1.4489299e+02  6.3800000e+03]
#  [ 6.3000000e+00  4.0000000e+00  1.0000000e+00 ... -3.7811880e+01
#    1.4488449e+02  6.5430000e+03]]
# Media calculada: [ 1.01377761e+01  2.91472754e+00  1.53424153e+00  1.61185567e+00
#   5.58416127e+02  1.39633972e+02  1.96678822e+03 -3.78092027e+01
#   1.44995216e+02  7.45441738e+03]
# Desviación estandar calculada: [5.86850886e+00 9.65885497e-01 6.91686254e-01 9.60757680e-01
#  3.99052231e+03 3.92202962e+02 2.90875714e+01 7.92569043e-02
#  1.03911735e-01 4.37842055e+03]
# [[-1.30148498e+00 -9.47035175e-01 -7.72375522e-01 ...  1.21159582e-01
#    3.06395829e-02 -7.84624806e-01]
#  [-1.30148498e+00 -9.47035175e-01 -7.72375522e-01 ...  1.64368448e-02
#   -1.74781777e-02 -7.84624806e-01]
#  [-1.30148498e+00  8.82842322e-02  6.73366668e-01 ... -1.22723149e-03
#   -7.85462560e-03 -7.84624806e-01]
#  ...
#  [-5.68760518e-01  8.82842322e-02  6.73366668e-01 ... -5.49318283e-01
#   -1.03776717e+00 -2.45389260e-01]
#  [-5.68760518e-01  1.12360364e+00 -7.72375522e-01 ... -6.29311314e-01
#   -9.83779046e-01 -2.45389260e-01]
#  [-6.53961037e-01  1.12360364e+00 -7.72375522e-01 ... -3.37796006e-02
#   -1.06557924e+00 -2.08161223e-01]]

# %% [markdown]
# Despues de `featureNormalize` la funcion es provada, se añade el temino de interseccion a `X_norm`:

# %%
X = np.concatenate([np.ones((m, 1)), X_norm], axis=1)

# %%
print(X)
# Out:
# [[ 1.00000000e+00 -1.30148498e+00 -9.47035175e-01 ...  1.21159582e-01
#    3.06395829e-02 -7.84624806e-01]
#  [ 1.00000000e+00 -1.30148498e+00 -9.47035175e-01 ...  1.64368448e-02
#   -1.74781777e-02 -7.84624806e-01]
#  [ 1.00000000e+00 -1.30148498e+00  8.82842322e-02 ... -1.22723149e-03
#   -7.85462560e-03 -7.84624806e-01]
#  ...
#  [ 1.00000000e+00 -5.68760518e-01  8.82842322e-02 ... -5.49318283e-01
#   -1.03776717e+00 -2.45389260e-01]
#  [ 1.00000000e+00 -5.68760518e-01  1.12360364e+00 ... -6.29311314e-01
#   -9.83779046e-01 -2.45389260e-01]
#  [ 1.00000000e+00 -6.53961037e-01  1.12360364e+00 ... -3.37796006e-02
#   -1.06557924e+00 -2.08161223e-01]]

# %% [markdown]
# ### Descenso por el gradiente

# %% [markdown]
# Esta función `computeCostMulti` calcula el costo. Recibe como parámetros la matriz de características `X`, el vector de valores reales `y` y los parámetros del modelo `theta`. Primero obtiene el número de ejemplos de entrenamiento `m`, luego calcula la diferencia entre las predicciones del modelo (`np.dot(X, theta)`) y los valores reales `y`, eleva esas diferencias al cuadrado, las suma y finalmente divide entre `2m`. El resultado `J` representa el error promedio cuadrático del modelo, que sirve para evaluar qué tan bien se ajustan los parámetros `theta` a los datos.

# %%
def computeCostMulti(X, y, theta):
    # Inicializa algunos valores utiles
    m = y.shape[0] # numero de ejemplos de entrenamiento

    J = 0

    # h = np.dot(X, theta)

    J = (1/(2 * m)) * np.sum(np.square(np.dot(X, theta) - y))

    return J

# %% [markdown]
# gradientDescentMulti implementa el descenso por gradiente para múltiples variables.
# Recibe los datos de entrada, las etiquetas, los parámetros iniciales, la tasa de aprendizaje y el número de iteraciones.
# En cada iteración actualiza theta minimizando el costo y guarda la evolución en J_history.
# Finalmente retorna los parámetros ajustados y el historial de costos.

# %%
def gradientDescentMulti(X, y, theta, alpha, num_iters):

    m = y.shape[0]

    theta = theta.copy()

    J_history = []

    for i in range(num_iters):
        theta = theta - (alpha / m) * (np.dot(X, theta) - y).dot(X)
        J_history.append(computeCostMulti(X, y, theta))

    return theta, J_history

# %% [markdown]
# Bloque comentado que limpiaba valores NaN, infinitos y precios extremos antes de entrenar, además de escalar y para facilitar el entrenamiento. Pero se decidió ya no realizarlo a la perdida de datos.

# %%
# print("Verificando datos...")
# print("¿Hay NaN en X?:", np.isnan(X).any())
# print("¿Hay NaN en y?:", np.isnan(y).any())
# print("¿Hay infinitos en X?:", np.isinf(X).any())
# print("¿Hay infinitos en y?:", np.isinf(y).any())

# X_clean = np.nan_to_num(X)
# y_clean = np.nan_to_num(y)

# mask = (y_clean > 0) & (y_clean < 10000000)
# X_clean = X_clean[mask]
# y_clean = y_clean[mask]

# print(f"Datos después de limpiar: {len(y_clean)} ejemplos")

# Escalar solo y
# y_scaled = y_clean / 1000000

# %% [markdown]
# Se define la tasa de aprendizaje y número de iteraciones, se inicializa theta, se entrena el modelo con gradientDescentMulti, se grafica la convergencia del costo, y se prepara un vector de ejemplo X_array que se normaliza para predecir el precio de una casa usando el modelo entrenado.

# %%
y_scaled = y / 1000000

alpha = 0.01
num_iters = 50000

theta = np.zeros(X.shape[1])

theta, J_history = gradientDescentMulti(X, y_scaled, theta, alpha, num_iters)

# Grafica la convergencia del costo
pyplot.plot(np.arange(len(J_history)), J_history, lw=2)
pyplot.xlabel('Numero de iteraciones')
pyplot.ylabel('Costo J')

print('theta calculado por el descenso por el gradiente: {:s}'.format(str(theta)))

X_array = np.ones(X.shape[1])
X_array[1] = 10    # Distance
X_array[2] = 3     # Bedroom2
X_array[3] = 2     # Bathroom
X_array[4] = 2     # Car
X_array[5] = 500   # Landsize
X_array[6] = 120   # BuildingArea
X_array[7] = 2000  # YearBuilt
X_array[8] = -37.8 # Lattitude
X_array[9] = 144.9 # Longtitude
X_array[10] = 8000 # Propertycount

# Normalizar
X_array[1:] = (X_array[1:] - mu) / sigma
X_array = np.nan_to_num(X_array)

price = np.dot(X_array, theta) * 1000000

print('El precio predecido: ${:.0f}'.format(price))
# Out:
# theta calculado por el descenso por el gradiente: [ 1.07568408 -0.22682359  0.23293046  0.16125369  0.06770805  0.01462599
#   0.02588822 -0.13029114 -0.11808262  0.0959241  -0.00994018]
# El precio predecido: $984389

# %% [markdown]
# Esta celda crea un vector de características `X_array` inicializado con unos, para luego asignar valores específicos que representan las propiedades de una vivienda. Posteriormente, **él** normaliza estas características (excepto el término de intercepción) restando la media (`mu`) y dividiendo por la desviación estándar (`sigma`), asegurándose de reemplazar cualquier `NaN` resultante por cero. **Este proceso** estandariza los datos para que estén en una escala comparable.

# %%
X_array = np.ones(X.shape[1])
X_array[1] = 5.0      # Distance (km del CBD)
X_array[2] = 3        # Bedroom2 (3 dormitorios)
X_array[3] = 2        # Bathroom (2 baños)
X_array[4] = 1        # Car (1 espacio de auto)
X_array[5] = 600      # Landsize (600 m2)
X_array[6] = 150      # BuildingArea (150 m2)
X_array[7] = 1995     # YearBuilt (año 1995)
X_array[8] = -37.8    # Lattitude (Melbourne)
X_array[9] = 144.9    # Longtitude (Melbourne)
X_array[10] = 7000    # Propertycount

X_array[1:] = np.nan_to_num((X_array[1:] - mu) / sigma)

# %% [markdown]
# Esta celda calcula el precio predicho realizando el producto punto entre el vector de características normalizadas (`X_array`) y los parámetros del modelo (`theta`), y luego deshace la escalación multiplicando por 1,000,000. **Finalmente, imprime** el resultado formateado como un precio en dólares.

# %%
price = np.dot(X_array, theta) * 1000000  # Desescalar el precio

print('El precio predecido para una casa a 5km del CBD, con 3 dormitorios, 2 baños y 150m2 (usando el descenso por el gradiente): ${:.0f}'.format(price))
# Out:
# El precio predecido para una casa a 5km del CBD, con 3 dormitorios, 2 baños y 150m2 (usando el descenso por el gradiente): $1134184

# %% [markdown]
# ### Ecuacion de la Normal

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Lab2-Monsie/melb_data.csv')
df = df.fillna(df.median(numeric_only=True))
X = df[['Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
        'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
        'Propertycount']].values
y = df['Price'].values
m = y.size
print(m)
X = np.concatenate([np.ones((m, 1)), X], axis=1)
# Out:
# 13580

# %% [markdown]
# Esta celda calcula los parámetros óptimos (`theta`) para un modelo de regresión lineal utilizando la ecuación normal. **Este método** realiza una operación matricial que encuentra directamente la solución que minimiza el costo, evitando el proceso iterativo del descenso de gradiente. **La función** computa `(X^T * X)^-1 * X^T * y`, lo que proporciona una solución analítica exacta en un solo paso.

# %%
def normalEqn(X, y):

    theta = np.zeros(X.shape[1])

    theta = np.dot(np.dot(np.linalg.inv(np.dot(X.T,X)),X.T),y)

    return theta

# %% [markdown]
# En esta celda se prepara los datos originales añadiendo una columna de unos para el término de intercepción. **Posteriormente, utiliza** la función `normalEqn` para calcular los parámetros óptimos del modelo (`theta`) de manera analítica. **Finalmente, imprime** el vector de parámetros theta resultante, que representa la solución óptima encontrada por el método de la ecuación normal.

# %%
X_original = np.concatenate([np.ones((X.shape[0], 1)), df[['Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude', 'Propertycount']].values], axis=1)

theta = normalEqn(X, y);
print('Theta calculado a partir de la ecuación de la normal: {:s}'.format(str(theta)));
# Out:
# Theta calculado a partir de la ecuación de la normal: [-1.81071606e+08 -3.86509758e+04  2.41157428e+05  2.33131260e+05
#   7.04736020e+04  3.66518246e+00  6.60072098e+01 -4.47927174e+03
#  -1.48987170e+06  9.23130602e+05 -2.27026577e+00]

# %% [markdown]
# Se crea un vector de entrada de ejemplo (`X_array`) con unas y valores específicos para una propiedad. **Luego calcula** su precio predicho usando los parámetros óptimos (`theta`) obtenidos mediante la ecuación normal. **Finalmente, imprime** el resultado formateado como el valor de la vivienda.

# %%
X_array = np.ones(X.shape[1])
X_array[1] = 5.0      # Distance (5 km del CBD)
X_array[2] = 3        # Bedroom2 (3 dormitorios)
X_array[3] = 2        # Bathroom (2 baños)
X_array[4] = 1        # Car (1 espacio de auto)
X_array[5] = 600      # Landsize (600 m2)
X_array[6] = 150      # BuildingArea (150 m2)
X_array[7] = 1995     # YearBuilt (año 1995)
X_array[8] = -37.8    # Lattitude (Melbourne)
X_array[9] = 144.9    # Longtitude (Melbourne)
X_array[10] = 7000    # Propertycount


price = np.dot(X_array, theta)

print('Precio predecido para una casa a 5km del CBD, con 3 dormitorios, 2 baños y 150m2 (usando la ecuación de la normal): ${:.0f}'.format(price))
# Out:
# Precio predecido para una casa a 5km del CBD, con 3 dormitorios, 2 baños y 150m2 (usando la ecuación de la normal): $1134184

# %% [markdown]
# ## Ejercicio de programación Regresión Polinomial

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Lab2-Monsie/melb_data.csv')
df = df.fillna(df.median(numeric_only=True))
X = df[['Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
        'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
        'Propertycount']].values
y = df['Price'].values
m = y.size

for i in range(20):
    print('{:6.0f}{:8.0f}'.format(X[i, 0], y[i]))
# Out:
#      2 1480000
#      2 1035000
#      2 1465000
#      2  850000
#      2 1600000
#      2  941000
#      2 1876000
#      2 1636000
#      2  300000
#      2 1097000
#      2  700000
#      2 1350000
#      2  750000
#      2 1172500
#      2  441000
#      2 1310000
#      2 1200000
#      2 1176500
#      2  955000
#      2  890000

# %% [markdown]
# Se define una función para visualizar datos. **Esta función** crea una nueva figura y grafica los puntos con cruces rojas, estableciendo el precio de las casas en el eje Y y la distancia al centro urbano en el eje X.

# %%
def plotData(x, y):
    #Grafica los puntos x e y en una figura nueva.
    fig = pyplot.figure()  # abre una nueva figura
    pyplot.plot(x, y, 'ro', ms=10, mec='k')
    pyplot.ylabel('Precio de casas ($)')
    pyplot.xlabel('Distancia del CBD (km)')

# %%
plotData(X[:,0], y)

# %% [markdown]
# En esta celda expande el conjunto de características `X` al concatenarle una copia de sí mismo elevada al cuadrado (`X * X`). **Esta operación** agrega términos polinomiales de segundo grado (características cuadráticas) a cada característica original, permitiendo que un modelo lineal ajuste relaciones no lineales en los datos.

# %%
X = np.concatenate([X, X * X], axis=1)

# %%
print(X)
# Out:
# [[2.50000000e+00 2.00000000e+00 1.00000000e+00 ... 1.42880976e+03
#   2.10245360e+04 1.61523610e+07]
#  [2.50000000e+00 2.00000000e+00 1.00000000e+00 ... 1.42943730e+03
#   2.10230860e+04 1.61523610e+07]
#  [2.50000000e+00 3.00000000e+00 2.00000000e+00 ... 1.42954317e+03
#   2.10233760e+04 1.61523610e+07]
#  ...
#  [6.80000000e+00 3.00000000e+00 2.00000000e+00 ... 1.43282993e+03
#   2.09923529e+04 4.07044000e+07]
#  [6.80000000e+00 4.00000000e+00 1.00000000e+00 ... 1.43330994e+03
#   2.09939786e+04 4.07044000e+07]
#  [6.30000000e+00 4.00000000e+00 1.00000000e+00 ... 1.42973827e+03
#   2.09915154e+04 4.28108490e+07]]

# %% [markdown]
# Se define la función `featureNormalize` para estandarizar las características. **Calcula** la media (`mu`) y la desviación estándar (`sigma`) de cada columna de `X`. **Luego normaliza** los datos restando la media y dividiendo por la desviación estándar. **Finalmente retorna** los datos normalizados, junto con los parámetros de escalamiento.

# %%
def  featureNormalize(X):
    X_norm = X.copy()
    mu = np.zeros(X.shape[1])
    sigma = np.zeros(X.shape[1])

    mu = np.mean(X, axis = 0)
    sigma = np.std(X, axis = 0)
    X_norm = (X - mu) / sigma

    return X_norm, mu, sigma

# %%
# llama featureNormalize con los datos cargados
X_norm, mu, sigma = featureNormalize(X)

#print(X)
#print('Media calculada:', mu)
#print('Desviación estandar calculada:', sigma)
#print(X_norm)

# %%
print(X_norm)
# Out:
# [[-1.30148498e+00 -9.47035175e-01 -7.72375522e-01 ... -1.22137469e-01
#    3.02838732e-02 -6.50183101e-01]
#  [-1.30148498e+00 -9.47035175e-01 -7.72375522e-01 ... -1.74768304e-02
#   -1.78377406e-02 -6.50183101e-01]
#  [-1.30148498e+00  8.82842322e-02  6.73366668e-01 ...  1.79036094e-04
#   -8.21355059e-03 -6.50183101e-01]
#  ...
#  [-5.68760518e-01  8.82842322e-02  6.73366668e-01 ...  5.48340210e-01
#   -1.03781780e+00 -3.77708916e-01]
#  [-5.68760518e-01  1.12360364e+00 -7.72375522e-01 ...  6.28396112e-01
#   -9.83864718e-01 -3.77708916e-01]
#  [-6.53961037e-01  1.12360364e+00 -7.72375522e-01 ...  3.27179883e-02
#   -1.06561100e+00 -3.54331917e-01]]

# %% [markdown]
# Se grafica los datos normalizados. **Usa** la segunda columna de `X_norm` (distancia al CBD) en el eje X y el vector de precios `y` en el eje Y para visualizar la relación entre ambas variables después de la normalización.

# %%
plotData(X_norm[:,1], y)

# %%
X_norm = np.concatenate([X_norm, X_norm * X_norm], axis=1)

print(X_norm)
# Out:
# [[-1.30148498e+00 -9.47035175e-01 -7.72375522e-01 ...  1.49175613e-02
#    9.17112977e-04  4.22738065e-01]
#  [-1.30148498e+00 -9.47035175e-01 -7.72375522e-01 ...  3.05439601e-04
#    3.18184990e-04  4.22738065e-01]
#  [-1.30148498e+00  8.82842322e-02  6.73366668e-01 ...  3.20539230e-08
#    6.74624134e-05  4.22738065e-01]
#  ...
#  [-5.68760518e-01  8.82842322e-02  6.73366668e-01 ...  3.00676986e-01
#    1.07706579e+00  1.42664025e-01]
#  [-5.68760518e-01  1.12360364e+00 -7.72375522e-01 ...  3.94881674e-01
#    9.67989783e-01  1.42664025e-01]
#  [-6.53961037e-01  1.12360364e+00 -7.72375522e-01 ...  1.07046676e-03
#    1.13552681e+00  1.25551108e-01]]

# %% [markdown]
# ## Descenso por el gradiente Polinomial

# %%
def computeCostMulti(X, y, theta):
    m = y.shape[0]

    J = 0

    h = np.dot(X, theta)

    J = (1/(2 * m)) * np.sum(np.square(np.dot(X, theta) - y))

    return J

# %%
def gradientDescentMulti(X, y, theta, alpha, num_iters):

    m = y.shape[0]

    theta = theta.copy()

    J_history = []

    for i in range(num_iters):
        theta = theta - (alpha / m) * (np.dot(X, theta) - y).dot(X)
        J_history.append(computeCostMulti(X, y, theta))

    return theta, J_history

# %%
# print("Limpiando datos originales...")

# X_original = df[['Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
                # 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
                # 'Propertycount']].values

# mask = ~(np.isnan(X_original).any(axis=1) | np.isnan(y))
# X_clean = X_original[mask]
# y_clean = y[mask]

# print(f"Datos limpios: {len(y_clean)} ejemplos")

# X_poly = np.concatenate([X_clean, X_clean * X_clean], axis=1)
# X_norm, mu, sigma = featureNormalize(X_poly)
# X_final = np.concatenate([np.ones((len(y_clean), 1)), X_norm], axis=1)
df = df.fillna(df.median(numeric_only=True))

# %%
X_norm = (X[:, 1:] - np.mean(X[:, 1:], axis=0)) / np.std(X[:, 1:], axis=0)
X_normalized = np.column_stack([np.ones(X.shape[0]), X_norm])

mu = np.mean(X[:, 1:], axis=0)
sigma = np.std(X[:, 1:], axis=0)

# %% [markdown]
# Se entrena un modelo polinomial con descenso de gradiente. **Configura** una tasa de aprendizaje de 0.001 para 50,000 iteraciones, escalando los precios a millones. **Ejecuta** el algoritmo y grafica la convergencia del costo.

# %%
# Escalar y para el entrenamiento
y_scaled = y / 10000000000
y_mean = np.mean(y_scaled)
y_std = np.std(y_scaled)
y_normalized = (y_scaled - y_mean) / y_std

alpha = 0.001
num_iters = 50000

theta = np.zeros(X_normalized.shape[1])
theta, J_history = gradientDescentMulti(X_normalized, y_normalized, theta, alpha, num_iters)

pyplot.plot(np.arange(len(J_history)), J_history, lw=2)
pyplot.xlabel('Numero de iteraciones')
pyplot.ylabel('Costo J')

print('theta calculado por el descenso por el gradiente: {:s}'.format(str(theta)))

# Crear array para predicción
X_array = np.ones(X_normalized.shape[1])
X_array[1] = 5.0      # Distance
X_array[2] = 3        # Bedroom2
X_array[3] = 2        # Bathroom
X_array[4] = 1        # Car
X_array[5] = 600      # Landsize
X_array[6] = 150      # BuildingArea
X_array[7] = 1995     # YearBuilt
X_array[8] = -37.8    # Lattitude
X_array[9] = 144.9    # Longtitude
X_array[10] = 7000    # Propertycount

if X_normalized.shape[1] > 11:
    X_array[11:X_normalized.shape[1]] = X_array[1:X_normalized.shape[1]-10] ** 2

X_array[1:] = (X_array[1:] - mu) / sigma

# Predicción y conversión a escala original
price_normalized = np.dot(X_array, theta)
price = (price_normalized * y_std + y_mean) * 1000000  # Revertir normalización y escalado

print('Precio predecido para casa a 5km del CBD, 3 dormitorios, 150m2 (descenso por gradiente): ${:.0f}'.format(price))
# Out:
# theta calculado por el descenso por el gradiente: [-6.98497519e-16  4.98934428e-01  1.53638530e-01  6.42821496e-02
#   1.20394293e-01  3.33126532e-01 -7.28585401e-02 -9.41186182e-02
#   6.29405504e-02  1.62005415e-01 -3.00167226e-01 -2.00639957e-01
#   1.08455248e-01  8.80770656e-03 -9.64983178e-02 -2.98542749e-01
#  -1.49568757e-01  9.44990246e-02  6.19254387e-02 -1.69991894e-01]
# Precio predecido para casa a 5km del CBD, 3 dormitorios, 150m2 (descenso por gradiente): $3844760

# %% [markdown]
# Se crea un modelo lineal simple usando solo la distancia al CBD. **Calcula** los parámetros óptimos (`theta_simple`) con la ecuación normal. **Grafica** los datos originales y superpone la línea de regresión resultante para visualizar la relación lineal entre distancia y precio.

# %%
X_simple = np.column_stack([np.ones(m), X_original[:, 0]])
theta_simple = normalEqn(X_simple, y)

plotData(X_original[:, 0], y)
x_line = np.linspace(X_original[:, 0].min(), X_original[:, 0].max(), 100)
y_line = theta_simple[0] + theta_simple[1] * x_line
pyplot.plot(x_line, y_line, '-', color='blue')

# %%
X_array = np.ones(20)

# Asignar valores a las primeras características
X_array[1] = 23
X_array[2] = 529
for i in range(3, 11):
    X_array[i] = 0

# Calcular características polinómicas (9 características cuadráticas)
X_array[11:20] = X_array[1:10] ** 2

# Normalizar usando las dimensiones correctas
X_array[1:] = (X_array[1:] - mu) / sigma

print(X_array)
# Out:
# [ 1.00000000e+00  2.07946724e+01  7.62579501e+02 -1.67769220e+00
#  -1.39935598e-01 -3.56024777e-01 -6.76161027e+01  4.77046171e+02
#  -1.39536902e+03 -1.70253572e+00 -7.18129882e-01  7.45285401e+01
#   9.55241866e+04 -7.25703352e-01 -1.00795773e-02 -1.01900678e-02
#  -3.43346322e+01 -2.38417075e+02 -6.97737448e+02 -8.29439146e-01]

# %%
X_array[1:3]
print(np.dot(X_array, theta))
# Out:
# 10284.117458582457

# %% [markdown]
# ## Ecuacion de la Normal con Polinomial

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Lab2-Monsie/melb_data.csv')

df = df.dropna()

X = df[['Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
        'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
        'Propertycount']].values
y = df['Price'].values
m = y.size

X_original = X.copy()
X = np.concatenate([X, X * X], axis=1)
X = np.concatenate([np.ones((m, 1)), X], axis=1)

# %%
def normalEqn(X, y):
    theta = np.zeros(X.shape[1])
    theta = np.dot(np.dot(np.linalg.inv(np.dot(X.T, X)), X.T), y)
    return theta


theta = normalEqn(X, y)
print('Theta calculado:', theta)
# Out:
# Theta calculado: [-5.05733343e+10 -4.66008828e+04  3.97420160e+05  4.82474140e+04
#   8.06819241e+04  6.76152648e+01  3.57230843e+03  1.50739509e+04
#  -3.09507211e+08  6.15558914e+08  1.76009452e+01  6.70198668e+02
#  -4.58340344e+04  3.67554273e+04 -3.98221710e+03 -2.56883758e-03
#  -1.17313607e+00 -5.01093183e+00 -4.07473859e+06 -2.11987281e+06
#  -9.21165257e-04]

# %% [markdown]
# Se crea manualmente un vector de características para una nueva propiedad, combinando valores originales y sus cuadrados. **Realiza** la predicción del precio mediante los parámetros dados en features para el modelo polinomial entrenado (`theta`). Finalmente imprime el resultado.

# %%
features = [5, 3, 2, 2, 500, 150, 2000, -37.8, 145.0, 8000]
features_squared = [x**2 for x in features]
X_array = [1] + features + features_squared

price = np.dot(X_array, theta)
print('Precio estimado: ${:.0f}'.format(price))
# Out:
# Precio estimado: $1286706

# %% [markdown]
# Se grafica la relación entre distancia y precio usando puntos rojos. **Genera** una línea de predicción manteniendo todas las demás características en sus valores promedio mientras varía solo la distancia. **Calcula** los precios predichos usando el modelo polinomial entrenado (`theta`) y superpone la curva azul resultante sobre los datos originales.

# %%
def plotData(x, y):
    pyplot.scatter(x, y, marker='o', c='r', s=40, linewidths=2)
    pyplot.xlabel('Distance')
    pyplot.ylabel('Price')

plotData(X[:, 1], y)

x_line = np.linspace(X[:, 1].min(), X[:, 1].max(), 50)
X_avg = np.mean(X, axis=0)

X_line = np.array([X_avg] * 50)
X_line[:, 1] = x_line
X_line[:, 11] = x_line**2

y_line = np.dot(X_line, theta)
pyplot.plot(x_line, y_line, '-', color='blue')
pyplot.show()

# %% [markdown]
# Esta celda utiliza el modelo de regresión lineal entrenado por descenso de gradiente para hacer predicciones sobre las primeras 100 casas del conjunto de datos. Primero define num_predictions = 100 y selecciona las primeras 100 filas de X como X_predict. Luego calcula las predicciones multiplicando X_predict por los parámetros theta y desescalando el resultado multiplicando por 1,000,000. Finalmente, imprime todas las 100 predicciones, mostrando cada precio estimado formateado como valor en dólares.

# %%
num_predictions = 100
X_predict = X[:num_predictions, :]
predictions_gd = np.dot(X_predict, theta)

print("Primeras 100 predicciones (Descenso de Gradiente):")
for i in range(100):
    print(f"Predicción {i+1}: ${predictions_gd[i]:.0f}")
# Out:
# Primeras 100 predicciones (Descenso de Gradiente):
# Predicción 1: $1087989
# Predicción 2: $1650605
# Predicción 3: $1090158
# Predicción 4: $1877646
# Predicción 5: $1372148
# Predicción 6: $1387037
# Predicción 7: $1456995
# Predicción 8: $873649
# Predicción 9: $1343595
# Predicción 10: $1666236
# Predicción 11: $1284247
# Predicción 12: $766479
# Predicción 13: $1864090
# Predicción 14: $781163
# Predicción 15: $998233
# Predicción 16: $1108300
# Predicción 17: $1524724
# Predicción 18: $1460789
# Predicción 19: $1264597
# Predicción 20: $281598
# Predicción 21: $1121731
# Predicción 22: $1208808
# Predicción 23: $1095083
# Predicción 24: $1050947
# Predicción 25: $761020
# Predicción 26: $739882
# Predicción 27: $739882
# Predicción 28: $333001
# Predicción 29: $589860
# Predicción 30: $280468
# Predicción 31: $23248
# Predicción 32: $1123936
# Predicción 33: $-7534
# Predicción 34: $-13210
# Predicción 35: $36504
# Predicción 36: $834742
# Predicción 37: $524996
# Predicción 38: $450579
# Predicción 39: $596685
# Predicción 40: $628746
# Predicción 41: $256967
# Predicción 42: $1167393
# Predicción 43: $1681304
# Predicción 44: $1165128
# Predicción 45: $628372
# Predicción 46: $232006
# Predicción 47: $643432
# Predicción 48: $470238
# Predicción 49: $952886
# Predicción 50: $1066289
# Predicción 51: $1811371
# Predicción 52: $1594637
# Predicción 53: $1061496
# Predicción 54: $1941378
# Predicción 55: $1288470
# Predicción 56: $1227870
# Predicción 57: $1598456
# Predicción 58: $1872115
# Predicción 59: $1088430
# Predicción 60: $1152039
# Predicción 61: $1107097
# Predicción 62: $1693713
# Predicción 63: $1646658
# Predicción 64: $2291432
# Predicción 65: $1275199
# Predicción 66: $1518626
# Predicción 67: $323125
# Predicción 68: $1926504
# Predicción 69: $1750873
# Predicción 70: $1043584
# Predicción 71: $1740595
# Predicción 72: $697124
# Predicción 73: $1970167
# Predicción 74: $1689049
# Predicción 75: $2352774
# Predicción 76: $643560
# Predicción 77: $994592
# Predicción 78: $1271579
# Predicción 79: $1578320
# Predicción 80: $812225
# Predicción 81: $635219
# Predicción 82: $617389
# Predicción 83: $1956803
# Predicción 84: $1860761
# Predicción 85: $983148
# Predicción 86: $1537743
# Predicción 87: $354426
# Predicción 88: $936704
# Predicción 89: $1780524
# Predicción 90: $524700
# Predicción 91: $727222
# Predicción 92: $311570
# Predicción 93: $614442
# Predicción 94: $223438
# Predicción 95: $277256
# Predicción 96: $326083
# Predicción 97: $937236
# Predicción 98: $657730
# Predicción 99: $242717
# Predicción 100: $699457
